# %%
import os
# CUR_PATH = os.path.dirname(os.path.realpath(__file__))

from pptx import Presentation
PPT_PATH = "sample.pptx"
prs = Presentation(PPT_PATH)

# %% [markdown]
# ## 들어가는 내용
# ### 한 번만 들어가는 내용
# applicant_name,
# job,
# phone_number,
# slogan,
# experience,
# award,
# vision_slogan,
# vision_description,
# ### 여러 번 들어가는 내용
# project_name,
# outline,
# detail_content_title,
# detail_content,
# tech_domain,
# tech,

# %%
data_dict = {
    "applicant_name":"권기범",
    "job":"AI 개발자",
    "phone_number":"010-2464-5954",
    "slogan":"AI 개발자 시켜주세요",
    "experience":"이거 해봄",
    "award":"상 탔음",
    "vision_slogan":"돈 많이 벌거임",
    "vision_description":"돈 많이 주세요",
    "project_name":"탄소 배출량 관리 시스템",
    "outline":"개요입니다.",
    "detail_content_title":"구현한 내용",
    "detail_content":"탄소 배출량 예측 모델",
    "tech_domain":"AI",
    "tech":"pytorch"
}

# %%
text_runs = []
add_ids = []
i = 0
for idx, slide in enumerate(prs.slides):
    
    # 선택된 슬라이드 내 도형 순회
    for j, shape in enumerate(slide.shapes):
        
        # 도형에 텍스트 프레임이 없을 경우
        if not shape.has_text_frame:
            # 다음 도형 선택
            continue

        content_text_list = shape.text_frame.text.split('\n')

        for content_text in content_text_list:
            new_content_text = ''
            if content_text.startswith('{') and content_text.endswith('}'):
                print(data_dict[content_text[1:-1]])
                new_content_text += data_dict[content_text[1:-1]] + '\n'
        else:
            print(shape.text_frame.text)
            print(new_content_text)
            prs.slides[idx].shapes[j].text_frame.text = new_content_text.strip()
# Out:
# 포트폴리오
#
# AI 개발자
# {job}
# AI 개발자
#
# 권기범
# {applicant_name}
# 권기범
#
# 010-2464-5954
# {phone_number}
# 010-2464-5954
#
# EXPERIENCE
#
# 이거 해봄
# {experience}
# 이거 해봄
#
# 이거 해봄
# {experience}
# 이거 해봄
#
# 이거 해봄
# {experience}
# 이거 해봄
#
# 이거 해봄
# {experience}
# 이거 해봄
#
#
#
# “{slogan}”
#
# 지원자 {applicant_name} 입니다.
#
#
#
# AWARDS
#
# 상 탔음
# {award}
# 상 탔음
#
# 상 탔음
# {award}
# 상 탔음
#
#
#
# photo
#
# VISION
#
# 앞으로 나아갈 길
#
#
#
# “{vision_slogan}”
#
# 돈 많이 주세요
# {vision_description}
# 돈 많이 주세요
#
# PROJECT
#
# 탄소 배출량 관리 시스템
# 개요입니다.
# 구현한 내용
# 탄소 배출량 예측 모델
# {project_name}
# 개요
# {outline}
# {detail_content_title}
# {detail_content}
# 탄소 배출량 예측 모델
#
#
#
# 기술 스택
#
# AI
# pytorch
# {tech_domain}
# {tech}
# pytorch
#
# 감사합니다.
#
# AI 개발자
# 권기범
# {job}
# {applicant_name}
# 권기범

# %%
prs.save('./test.ppt')
